# %% [markdown]
# # Demo

# %%
from segmetrics import SampleMetrics

pred = "datas/pred.png"
label = "datas/label.png"
num_classes = 2

SampleMetrics(pred, label, num_classes)
# Out:
# ======= Metrics =======
# ◆ ConfusionMatrix
# [[148232   1397]
#  [   853   3118]]
# ◆ OA
# 0.9853515625
# ◆ Precision
# [0.99427843 0.69058693]
# ◆ Recall
# [0.99066357 0.78519265]
# ◆ FalseAlarm
# [0.00572157 0.30941307]
# ◆ MissingAlarm
# [0.00933643 0.21480735]
# ◆ F1
# [0.99246771 0.73485741]
# ◆ IoU
# [0.98504805 0.58084948]
# ◆ mIoU
# 0.7829487620019454
# ◆ FWIoU
# 0.9745983547902362
# ◆ Dice
# [0.99246771 0.73485741]
# ◆ mDice
# 0.8636625618993469
# ◆ Kappa
# 0.7273569535774774
